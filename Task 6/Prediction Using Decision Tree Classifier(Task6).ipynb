# %% [markdown]
# # GRIP : The Sparks Foundation

# %% [markdown]
# ## Data Science and Business Analytics Intern
# ### Author : Pavan Wanjari

# %% [markdown]
# ### Task 6 :- Prediction Using Decision Tree Classifier

# %% [markdown]
# Perform decision tree classifier on **iris.csv** dataset.
#
# A **Decision Tree** is a type of supervised learning algorithm which uses a tree like structure and is mostly used in classification problems and regression purposes.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Dataset

# %%
iris_df = pd.read_csv("iris.csv")
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Exploring data

# %%
iris_df.shape
# Out:
# (150, 6)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Checking the null values
iris_df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Checking descriptive statistics
iris_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
iris_df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# renaming the columns name 
iris_df.rename(columns={'SepalLengthCm':'sepal length (cm)','SepalWidthCm':'sepal width (cm)',
                   'PetalLengthCm':'petal length (cm)','PetalWidthCm':'petal width (cm)'}, inplace = True)

# %%
iris_df.head()
# Out:
#    Id  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    petal width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %% [markdown]
# ### Data visualization

# %%
sns.pairplot(data= iris_df, hue="Species")
plt.show()

# %% [markdown]
# From above pairplot we can observe that species "Iris Setosa" make distinctive cluster in every parameter, while other two species overlap.

# %% [markdown]
# **Find Correlation**

# %%
iris_df.corr()
# Out:
#                          Id  sepal length (cm)  sepal width (cm)  \
# Id                 1.000000           0.716676         -0.397729
# sepal length (cm)  0.716676           1.000000         -0.109369
# sepal width (cm)  -0.397729          -0.109369          1.000000
# petal length (cm)  0.882747           0.871754         -0.420516
# petal width (cm)   0.899759           0.817954         -0.356544
#
#                    petal length (cm)  petal width (cm)
# Id                          0.882747          0.899759
# sepal length (cm)           0.871754          0.817954
# sepal width (cm)           -0.420516         -0.356544
# petal length (cm)           1.000000          0.962757
# petal width (cm)            0.962757          1.000000

# %%
plt.figure(figsize=(11,7))
sns.heatmap(data= iris_df.corr(), annot= True, cmap="Oranges_r")

plt.xticks(fontsize = 12, rotation = 50 )
plt.yticks(fontsize = 12,  )

plt.show()

# %% [markdown]
# **Bright color** shows positive correlation &
# **Dark color** shows negative correlation

# %% [markdown]
# From above Heatmap we see **petel length (cm)** is highly correlated with **petal width (cm)**.
#
#
# **sepal width (cm)** and **petel length (cm)** is negatively correlated with each other.

# %% [markdown]
# ### Set a variable X equal to the features and a variable y equal to the target column.

# %%
# X for features
X = iris_df.drop(['Species',"Id"],axis=1)

#y for target column
y = iris_df['Species']

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %% [markdown]
# ### Train Test Split
# Now let's split the data into a training set and a testing set. We will train out model on the training set and then use the test set to evaluate the model. Taking training data 80% and 20% for model testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=19)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_train.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (120,)

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier() # dtree is instance of  DecisionTreeClassifier

dtree.fit(X_train,y_train)       # fitting training data
print("Decision Tree Algorithm is successfully implimented.")

y_pred = dtree.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

#confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:- ")
print(cm)

#accuracy test
accuracy = accuracy_score(y_test,y_pred)

print("accuracy:- ", accuracy*100)

print("Classification Report:-")
print(  classification_report(y_test, y_pred))
# Out:
# Decision Tree Algorithm is successfully implimented.
# Confusion Matrix:-
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  0  8]]
# accuracy:-  100.0
# Classification Report:-
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00        12
#  Iris-virginica       1.00      1.00      1.00         8
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %%
from sklearn import tree

fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']

cn=['setosa', 'versicolor', 'virginica']

fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (16,12), dpi=300)
tree.plot_tree(dtree,feature_names = fn, class_names=cn,fontsize=10,filled = True);
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Thank You !
